# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import plotly.express as px
from plotly.offline import plot, iplot, init_notebook_mode
import plotly.graph_objs as go
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.6.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#df = px.data.gapminder().query("year==2007 and continent=='Europe'")
#print(df)

#fig = px.scatter(df, x="gdpPercap", y="lifeExp", text="country", log_x=True, size_max=100, color="lifeExp")
#fig.update_traces(textposition='top center')
#fig.update_layout(title_text='Life Expectency', title_x=0.5)

#fig.show()


df = pd.read_excel(r'/Users/maria/Documents/GFK_121011/160037/plots/160037_ng.xlsx')
print(df)


fig = px.scatter(df, x="Важность", y="Обладание знанием", text="N", hover_name="Высказывание", size_max=100, color="Важность")
fig.update_traces(textposition='top center')
#fig.update_layout(title_text='Life Expectency', title_x=0.5)

fig.show()
# Out:
#      N                                       Высказывание  Важность  \
# 0    1          Земельное/трудовое/административное право       392
# 1    2                         Налоговое законодательство       292
# 2    3  Правовые основы, организация и структура орган...       676
# 3    4                Методы повышения доходности бюджета       402
# 4    5                Бухгалтерский и управленческий учет       263
# 5    6                              Финансовый менеджмент       467
# 6    7                                     Работа с 44 ФЗ       520
# 7    8                                   Иностранный язык       138
# 8    9          Развитие территорий: управление проектами       657
# 9   10           Макроэкономика России: актуальные тренды       283
# 10  11                     Цифровизация экономики региона       531
# 11  12                Цифровизация и автоматизация данных       623
# 12  13                Практики территорий по работе с ТБО       104
# ...
